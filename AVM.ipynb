# %% [markdown]
# ![zillow_logo](https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcQ9tXP7gpE9TiWMCTXHxwmqHlqWeUO--V_sQEcfl3Ad75fjkHc_PQ)
# # Zillow.com Interview Excercise Redo
# **Author**: Yi Zhang
# **Date**: Nov/01/2014
# ### Ooutline:
# a. **Data Preparation**
#  * Data Preparation/Munging/Cleaning
#  * Data Exploration: Feature Selection/Correlation/Importance
#  * Missing Value Handling
#  * Feature Extraction/Creation
#  * External Data Source
#
# b. **Linear Regression**
#  * **Linear Model Development and Selection**
#    * **3 Subsets Schema: Train, Validation and Test**
#    * **Model Selection: Cross-validation**
#      * S1: K-fold cross-validation, dividing data (trianing),
#      * S2: For each fold k = 1, 2, ..., K
#        * S2-1: Find a subset of "good" predictor
#        * S2-2: Using just this subset of predictors, building a multivariate model with all (k-1) folds
#        * S3-3: Validate the model with K th fold data
#  * Customized Loss Function
#  * Specialized Model Development
#  * Regression Model Blending
#  * Model Assessment
#  * Model Performance on Map
#
# c. **Alertnative Model Development**
#  * SVM and Grid Search
#  * RandomForest and its Interpratation
#  * Boosting and its Intrepratation
#  * Ensembling: Linear Ensembler and Non-linear Ensembler
#  * Model Evaluation
#
# d. **Final Discussion**
#  * Production Model Choice
#  * Volecity in Price Estimation
#  * Dicussion
#
# e. **Recommendation System Design**
#
# ### Model Building/Selection
#  * Model Development, gridsearch, bias-variance plot
#  * Cost-function customization
#  * Segementation Strategy
#
# ### Model Diagnosis
#  * Analysis each models
#
# ### Address issues:
#  * Consistancy of Prediction

# %%
## ---------- IPython functionality --------------- ##
from IPython.display import HTML
## ---------- Data Structure ---------------------- ##
import numpy as np
import pandas as pd
## ---------- Data Visualization ------------------ ##
import matplotlib as mpt
import matplotlib.pyplot as plt
import seaborn
import folium
import vincent
## ---------- Colors System ----------------------- ##

## ---------- Scipy: Staistics -------------------- ##
from scipy import stats
## ---------- System, Environment ----------------- ##
import os
## ---------- Dollar Amount Format ---------------- ##
import locale


## ---------- Global Setting ---------------------- ##
# %matplotlib inline
locale.setlocale( locale.LC_ALL, '' ) ## Set US as local
## ---------- Environment Variable ---------------- ##
DATA_PATH = os.getcwd() + '/data/'

# %%
## ###################
## Load data
## ###################
## Import zillow Project-specific datasets
train_df = pd.read_csv(DATA_PATH + 'training.csv', header=0)
valid_df = pd.read_csv(DATA_PATH + 'validation.csv', header=0)
train_df = train_df.set_index('propertyid')
valid_df = valid_df.set_index('propertyid')
## Import External datasets
cpi_df = pd.read_csv(os.getcwd() + '/data/cpi_us_1937_2005.csv', header=0)
neig_df = pd.read_csv(os.getcwd() + '/data/zbp05totals.txt', header=0)
zprice_df = pd.read_csv(os.getcwd() + '/data/ZILLOW_ZIP_PRICE.csv', header=0)
zip_df = pd.read_csv(os.getcwd() + '/data/ZIP_TRACT_032010.csv', header=0)

# %%
train_df.head()
# Out:
#              transdate  transvalue transdate_previous  transvalue_previous  \
# propertyid
# 48650729    11/16/2005      231000         12/16/1994               129500
# 48650769     9/23/2005      229950          11/3/1998               138000
# 48650769     9/23/2005      229950          7/26/2002               184000
# 48650837    11/29/2005       60000                NaN                  NaN
# 48651057    11/16/2005     1010000          5/30/1995               552000
#
#             bathroomcnt  bedroomcnt  builtyear  finishedsquarefeet  \
# propertyid
# 48650729           2.00           3       1964                2110
# 48650769           0.75           2       1942                1220
# 48650769           0.75           2       1942                1220
# 48650837           1.00           3       1935                1060
# 48651057           2.25           4       1991                5410
#
#             lotsizesquarefeet  storycnt  latitude  longitude  usecode  \
# propertyid
# 48650729                 8413         1  47469470 -122282926        9
# 48650769                16867         1  47468266 -122283976        9
# 48650769                16867         1  47468266 -122283976        9
# 48650837                39060         1  47469990 -122275028        9
# 48651057                15002         1  47332382 -122355990        9
#
#             censustract  viewtypeid
# propertyid
# 48650729          28200         NaN
# 48650769          28200         NaN
# 48650769          28200         NaN
# 48650837          28200         NaN
# 48651057          30100           3

# %%
train_df.info()
valid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2553 entries, 48650729 to 68475077
# Data columns (total 15 columns):
# transdate              2553 non-null object
# transvalue             2553 non-null int64
# transdate_previous     1681 non-null object
# transvalue_previous    1681 non-null float64
# bathroomcnt            2538 non-null float64
# bedroomcnt             2536 non-null float64
# builtyear              2539 non-null float64
# finishedsquarefeet     2539 non-null float64
# lotsizesquarefeet      2553 non-null int64
# storycnt               2539 non-null float64
# latitude               2553 non-null int64
# longitude              2553 non-null int64
# usecode                2553 non-null int64
# censustract            2549 non-null float64
# viewtypeid             558 non-null float64
# dtypes: float64(8), int64(5), object(2)<class 'pandas.core.frame.DataFrame'>
# Int64Index: 2496 entries, 48649606 to 68474494
# Data columns (total 15 columns):
# transdate              2496 non-null object
# transvalue             2496 non-null int64
# transdate_previous     1674 non-null object
# transvalue_previous    1674 non-null float64
# bathroomcnt            2492 non-null float64
# bedroomcnt             2488 non-null float64
# builtyear              2493 non-null float64
# finishedsquarefeet     2493 non-null float64
# lotsizesquarefeet      2496 non-null int64
# storycnt               2493 non-null float64
# latitude               2496 non-null int64
# longitude              2496 non-null int64
# usecode                2496 non-null int64
# censustract            2496 non-null int64
# viewtypeid             553 non-null float64
# dtypes: float64(7), int64(6), object(2)

# %%
train_missing = pd.DataFrame([[i, train_df[i].isnull().sum()] for i in train_df.columns], columns = ['var_name', 'missing_count'])
valid_missing = pd.DataFrame([[i, valid_df[i].isnull().sum()] for i in valid_df.columns], columns = ['var_name', 'missing_count'])
train_missing['non_missing_count'] = train_df.shape[0] - train_missing['missing_count'] 
valid_missing['non_missing_count'] = valid_df.shape[0] - valid_missing['missing_count']

# %%
train_missing
# Out:
#                var_name  missing_count  non_missing_count
# 0             transdate              0               2553
# 1            transvalue              0               2553
# 2    transdate_previous            872               1681
# 3   transvalue_previous            872               1681
# 4           bathroomcnt             15               2538
# 5            bedroomcnt             17               2536
# 6             builtyear             14               2539
# 7    finishedsquarefeet             14               2539
# 8     lotsizesquarefeet              0               2553
# 9              storycnt             14               2539
# 10             latitude              0               2553
# 11            longitude              0               2553
# 12              usecode              0               2553
# 13          censustract              4               2549
# 14           viewtypeid           1995                558

# %%
sns.set_palette("deep", desat = .6)
sns.set_context(rc={"figure.figsize": (8, 4)})
np.random.seed(9123)

# %% [markdown]
# ## 2. Exploratory Analysis
# ### a. Data Visualization: TransValue vs. Unit Properties
#   a-1. **Distribution of log(TransValue)**

# %%
sns.distplot(np.log10(train_df['transvalue'])
             , rug=False
             , hist=True
             , kde_kws={"color": "seagreen", "lw": 3, "label": "KDE"}
             , hist_kws={"histtype": "stepfilled", "color": "slategray"})

# %%
def inline_map(map):
    """
    Embeds the HTML source of the map directly into the IPython notebook.
    
    This method will not work if the map depends on any files (json data). Also this uses
    the HTML5 srcdoc attribute, which may not be supported in all browsers.
    """
    map._build_map()
    return HTML('<iframe srcdoc="{srcdoc}" style="width: 100%; height: 510px; border: none"></iframe>'.format(srcdoc=map.HTML.replace('"', '&quot;')))

def embed_map(map, path="map.html"):
    """
    Embeds a linked iframe to the map into the IPython notebook.
    
    Note: this method will not capture the source of the map into the notebook.
    This method should work for all maps (as long as they use relative urls).
    """
    map.create_map(path=path)
    return HTML('<iframe src="files/{path}" style="width: 100%; height: 510px; border: none"></iframe>'.format(path=path))

def realEstateMap(data):
    """
    Display the house information on Map
    
    Parameters
    ----------
    data: {array-like}, shape = (n_samples, n_features)
    
    Returns
    -------
    map: folium map object
    """
    center = [data['latitude'].mean(), data['longitude'].mean()]
    map = folium.Map(location= center, zoom_start=10, tiles='Stamen Toner')
    colors = pd.Series(['medium green', 'pale red']).apply(lambda x: sns.xkcd_rgb[x])
    for i, row in data.iterrows():
        #label = 'ID: ' + str(int(row['propertyid'])) + '; Price: ' + locale.currency(row['transvalue'], grouping=True )
        #label = 'ID: ' + str(int(row.index)) + '; Price: ' + locale.currency(row['transvalue'], grouping=True )
        label = 'Price: ' + locale.currency(row['transvalue'], grouping=True )
        loc = [row['latitude'], row['longitude']]
        color = colors[0] if row['transvalue'] <= 459609 else colors[1]
        map.circle_marker(loc, popup=label, fill_color=color)
    return map

# %%
## geo-info formatting
train_df['latitude'] = train_df['latitude'].astype(np.float) / 1000000
train_df['longitude'] = train_df['longitude'].astype(np.float) / 1000000
## Plot units on map
train_sample = train_df.loc[np.random.choice(train_df.index, 100, replace=False)]
map = realEstateMap(train_sample)
inline_map(map)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <link rel=&quot;stylesheet&quot; href=&quot;http://cdn.leafletjs.com/leaflet-0.5/leaflet.css&quot; />
#    <script src=&quot;http://cdn.leafletjs.com/leaflet-0.5/leaflet.js&quot;></script>
#
#
#
#
#
#
# <style>
#
# #map {
#   position:absolute;
#   top:0;
#   bottom:0;
#   right:0;
#   left:0;
# }
#
# </style>
# </head>
# <body>
#
#         <div id=&quot;map&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
# <script>
#
#
#
# var map = L.map('map').setView([47.5211965407, -122.226270852], 10);
#
# L.tileLayer('http://{s}.tile.stamen.com/toner/{z}/{x}/{y}.jpg', {
#     maxZoom: 18,
#     attribution: 'Map tiles by <a href=&quot;http://stamen.com&quot;>Stamen Design</a>, under <a href=&quot;http://creativecommons.org/licenses/by/3.0&quot;>CC BY 3.0</a>. Data by <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a>, under <a href=&quot;http://creativecommons.org/licenses/by-sa/3.0&quot;>CC BY SA</a>.'
# }).addTo(map);
#
#
# var circle_1 = L.circle([47.530595, -121.847581], 500, {
#                             color: 'black',
#                             fillColor: '#39ad48',
#                             fillOpacity: 0.6
#                             });
# circle_1.bindPopup(&quot;Price: $450,000.00&quot;);
# map.addLayer(circle_1)
#
# var circle_2 = L.circle([47.596897, -122.294856], 500, {
#                             color: 'black',
#                             fillColor: '#d9544d',
#                             fillOpacity: 0.6
#                             });
# circle_2.bindPopup(&quot;Price: $647,000.00&quot;);
# map.addLayer(circle_2)
#
# var circle_3 = L.circle([47.596897, -122.294856], 500, {
#                             color: 'black',
#                             fillColor: '#d9544d',
#                             fillOpacity: 0.6
#                             });
# circle_3.bindPopup(&quot;Price: $647,000.00&quot;);
# map.addLayer(circle_3)
#
# var circle_4 = L.circle([47.716776, -122.335915], 500, {
#                             color: 'black',
#                             fillColor: '#39ad48',
#                             fillOpacity: 0.6
#                             });
# circle_4.bindPopup(&quot;Price: $327,500.00&quot;);
# map.addLayer(circle_4)
#
# var circle_5 = L.circle([47.683274, -122.32598], 500, {
#                             color: 'black',
#                             fillColor: '#d9544d',
#                             fillOpacity: 0.6
#                             });
# circle_5.bindPopup(&quot;Price: $625,000.00&quot;);
# map.addLayer(circle_5)
#
# var circle_6 = L.circle([47.468266, -122.283976], 500, {
#                             color: 'black',
#                             fillColor: '#39ad48',
#                             fillOpacity: 0.6
#                             });
# circle_6.bindPopup(&quot;Price: $229,950.00&quot;);
# map.addLayer(circle_6)
#
# var circle_7 = L.circle([47.468266, -122.283976], 500, {
#                             color: 'black',
#                             fillColor: '#39ad48',
#                             fillOpacity: 0.6
#                             });
# circle_7.bindPopup(&quot;Price: $229,950.00&quot;);
# map.addLayer(circle_7)
#
# var circle_8 = L.circle([47.417915, -122.201847], 500, {
#                             color: 'black',
#                             fillColor: '#39ad48',
#                             fillOpacity: 0.6
#                             });
# circle_8.bindPopup(&quot;Price: $292,000.00&quot;);
# map.addLayer(circle_8)
#
# var circle_9 = L.circle([47.417915, -122.201847], 500, {
#                             color: 'black',
#                             fillColor: '#39ad48',
#                             fillOpacity: 0.6
#                             });
# circle_9.bindPopup(&quot;Price: $292,000.00&quot;);
# map.addLayer(circle_9)
#
# var circle_10 = L.circle([47.677823, -122.389498], 500, {
#                             color: 'black',
#                             fillColor: '#d9544d',
#                             fillOpacity: 0.6
#                             });
# circle_10.bindPopup(&quot;Price: $495,000.00&quot;);
# map.addLayer(circle_10)
#
# var circle_11 = L.circle([47.308726, -122.206524], 500, {
#                             color: 'black',
#                             fillColor: '#39ad48',
#                             fillOpacity: 0.6
#                             });
# circle_11.bindPopup(&quot;Price: $252,000.00&quot;);
# map.addLayer(circle_11)
#
# var circle_12 = L.circle([47.364367, -122.159635], 500, {
#                             color: 'black',
#                             fillColor: '#d9544d',
#                             fillOpacity: 0.6
#                             });
# circle_12.bindPopup(&quot;Price: $995,000.00&quot;);
# map.addLayer(circle_12)
#
# var circle_13 = L.circle([47.674901, -122.309473], 500, {
#                             color: 'black',
#                             fillColor: '#d9544d',
#                             fillOpacity: 0.6
#                             });
# circle_13.bindPopup(&quot;Price: $751,650.00&quot;);
# map.addLayer(circle_13)
#
# var circle_14 = L.circle([47.678215, -122.305606], 500, {
#                             color: 'black',
#                             fillColor: '#39ad48',
#                             fillOpacity: 0.6
#                             });
# circle_14.bindPopup(&quot;Price: $419,000.00&quot;);
# map.addLayer(circle_14)
#
# var circle_15 = L.circle([47.454242, -121.718674], 500, {
#                             color: 'black',
#                             fillColor: '#d9544d',
#                             fillOpacity: 0.6
#                             });
# circle_15.bindPopup(&quot;Price: $750,000.00&quot;);
# map.addLayer(circle_15)
#
# var circle_16 = L.circle([47.453977, -122.288033], 500, {
#                             color: 'black',
#                             fillColor: '#39ad48',
#                             fillOpacity: 0.6
#                             });
# circle_16.bindPopup(&quot;Price: $253,000.00&quot;);
# map.addLayer(circle_16)
#
# var circle_17 = L.circle([47.68276, -122.202361], 500, {
#                             color: 'black',
#                             fillColor: '#39ad48',
#                             fillOpacity: 0.6
#                             });
# circle_17.bindPopup(&quot;Price: $425,000.00&quot;);
# map.addLayer(circle_17)
#
# var circle_18 = L.circle([47.546551, -122.175322], 500, {
#                             color: 'black',
#                             fillColor: '#39ad48',
#                             fillOpacity: 0.6
#                             });
# circle_18.bindPopup(&quot;Price: $365,000.00&quot;);
# map.addLayer(circle_18)
#
# var circle_19 = L.circle([47.534017, -122.1546], 500, {
#                             color: 'black',
#                             fillColor: '#d9544d',
#                             fillOpacity: 0.6
#                             });
# circle_19.bindPopup(&quot;Price: $650,000.00&quot;);
# map.addLayer(circle_19)
#
# var circle_20 = L.circle([47.629763, -122.287625], 500, {
#                             color: 'black',
#                             fillColor: '#d9544d',
#                             fillOpacity: 0.6
#                             });
# circle_20.bindPopup(&quot;Price: $1,090,000.00&quot;);
# map.addLayer(circle_20)
#
# var circle_21 = L.circle([47.629763, -122.287625], 500, {
#                             color: 'black',
#                             fillColor: '#d9544d',
#                             fillOpacity: 0.6
#                             });
# circle_21.bindPopup(&quot;Price: $1,090,000.00&quot;);
# map.addLayer(circle_21)
#
# var circle_22 = L.circle([47.734709, -122.218872], 500, {
#                             color: 'black',
#                             fillColor: '#39ad48',
#                             fillOpacity: 0.6
#                             });
# circle_22.bindPopup(&quot;Price: $435,000.00&quot;);
# map.addLayer(circle_22)
#
# var circle_23 = L.circle([47.299616, -122.12905], 500, {
#                             color: 'black',
#                             fillColor: '#d9544d',
#                             fillOpacity: 0.6
#                             });
# circle_23.bindPopup(&quot;Price: $549,900.00&quot;);
# map.addLayer(circle_23)
#
# var circle_24

# %%
## ################## ##
## Transform variable ##
## ################## ##
## Date variable
train_df['transdate'] = pd.to_datetime(train_df['transdate'])
train_df['transdate_previous'] = pd.to_datetime(train_df['transdate_previous'])
